# %%
import pandas as pd
import requests
import json
import numpy as np
import geopandas as gpd

# %% [markdown]
# ## Funkcje

# %%
def get_df (page_url):
    response_API = requests.get(page_url)
    population_summary = json.loads(response_API.text)
    rows = []

    for data in population_summary['results']:
        for value in data['values']:
            row = {'id': data['id'],
                'name': data['name'],
                'year': value['year'],
                'value': value['val'],
                'powiat_numer': data['id'][2:4] + data['id'][7:9]}
            rows.append(row)
    df = pd.DataFrame(rows)
    return df

# %%
def transform_population_df(population_df):
    population_df_copy = population_df.copy()
    population_df_copy['name_normalized'] = population_df['name'].str.replace('Powiat', '')
    population_df_copy['name_normalized'] = population_df_copy['name_normalized'].str.replace(' m.', '')
    population_df_copy['name_normalized'] = population_df_copy['name_normalized'].str.lstrip()
    population_df_copy['name_normalized'] = population_df_copy['name_normalized'].str.replace('Wałbrzych od 2013', 'Wałbrzych')
    population_df_copy['name_normalized'] = population_df_copy['name_normalized'].str.replace('Wałbrzych do 2002', 'Wałbrzych')
    population_df_copy['name_normalized'] = population_df_copy['name_normalized'].str.replace('st. Warszawa', 'Warszawa')
    population_df_copy['powiat_numer'] = population_df_copy['powiat_numer'].astype('int').astype('str')
    population_df_copy = population_df_copy.rename(columns={'value':'population'})
    return population_df_copy

# %%
def get_total_df(deaths_path):
    ALL_DATA = pd.read_csv(deaths_path)
    poviats_data_Y = ALL_DATA.query('powiat_numer > 32')
    total_df = poviats_data_Y.query(f'wiek_eurostat != "TOTAL"')
    total_df_copy = total_df.copy()
    total_df_copy['name_normalized'] = total_df_copy['powiat_nazwa']
    total_df_copy = total_df_copy.rename(columns={'YEAR':'year', 'sum':'deaths'})
    total_df_copy['year'] = total_df_copy['year'].astype('str')
    total_df_copy['powiat_numer'] = total_df_copy['powiat_numer'].astype('str') 

    return total_df_copy

# %%
def get_CMR_table(population_df, total_df):
    merged_df = pd.merge(population_df, total_df, on=['year', 'powiat_numer', 'age_group'], how='inner')
    merged_df = merged_df.rename(columns={'name_normalized_x':'name_normalized_pop', 'name_normalized_y':'name_normalized_tot'})
    # merged_df['CMR'] = merged_df['deaths']/merged_df['population']*100000

    return merged_df

# %% [markdown]
# ## Dla grupy ogółem

# %%
age_groups = """Y_LT5    72306
Y5-9    72307
Y10-14    72308
Y15-19    72309
Y20-24    47734
Y25-29    47694
Y30-34    47722
Y35-39    47701
Y40-44    47707
Y45-49    47726
Y50-54    47717
Y55-59    47732
Y60-64    47739
Y65-69    72239
Y70-74    76022
Y75-79    76023
Y80-84    76024
Y_GE85    76025"""

# Split the data into lines and then split each line into key and value
lines = age_groups.split("\n")
keys = []
values = []

for line in lines:
    key, value = line.split()
    keys.append(key)
    values.append(int(value))

# Create a dictionary from the keys and values lists
age_dict = dict(zip(keys, values))
print(age_dict)
# Out:
# {'Y_LT5': 72306, 'Y5-9': 72307, 'Y10-14': 72308, 'Y15-19': 72309, 'Y20-24': 47734, 'Y25-29': 47694, 'Y30-34': 47722, 'Y35-39': 47701, 'Y40-44': 47707, 'Y45-49': 47726, 'Y50-54': 47717, 'Y55-59': 47732, 'Y60-64': 47739, 'Y65-69': 72239, 'Y70-74': 76022, 'Y75-79': 76023, 'Y80-84': 76024, 'Y_GE85': 76025}

# %%
population_df = pd.DataFrame()

for k, v in age_dict.items():
    current_df = pd.DataFrame()
    page_0 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=0'
    page_1 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=1'
    page_2 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=2'
    page_3 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=3'
    df_0 = get_df(page_0)
    df_1 = get_df(page_1)
    df_2 = get_df(page_2)
    df_3 = get_df(page_3)
    dfs = [df_0, df_1, df_2, df_3]
    current_df = pd.concat(dfs, axis=0)
    current_df['age_group'] = str(k)
    population_df = pd.concat([population_df, current_df], axis=0)

# %%
population_df
# Out:
#                 id                name  year  value powiat_numer age_group
# 0     011212001000    Powiat bocheński  2000   6232         1201     Y_LT5
# 1     011212001000    Powiat bocheński  2001   6020         1201     Y_LT5
# 2     011212001000    Powiat bocheński  2002   5842         1201     Y_LT5
# 3     011212001000    Powiat bocheński  2003   5704         1201     Y_LT5
# 4     011212001000    Powiat bocheński  2004   5588         1201     Y_LT5
# ...            ...                 ...   ...    ...          ...       ...
# 1615  071427338000  Powiat żyrardowski  2017   1482         1438    Y_GE85
# 1616  071427338000  Powiat żyrardowski  2018   1467         1438    Y_GE85
# 1617  071427338000  Powiat żyrardowski  2019   1436         1438    Y_GE85
# 1618  071427338000  Powiat żyrardowski  2020   1392         1438    Y_GE85
# 1619  071427338000  Powiat żyrardowski  2021   1369         1438    Y_GE85
#
# [147064 rows x 6 columns]

# %% [markdown]
# Komentarz: dane dla osob 70+ są dostępne tylko od roku 2002

# %%
population_df.groupby('age_group').count()
# Out:
#              id  name  year  value  powiat_numer
# age_group
# Y10-14     8336  8336  8336   8336          8336
# Y15-19     8336  8336  8336   8336          8336
# Y20-24     8336  8336  8336   8336          8336
# Y25-29     8336  8336  8336   8336          8336
# Y30-34     8336  8336  8336   8336          8336
# Y35-39     8336  8336  8336   8336          8336
# Y40-44     8336  8336  8336   8336          8336
# Y45-49     8336  8336  8336   8336          8336
# Y5-9       8336  8336  8336   8336          8336
# Y50-54     8336  8336  8336   8336          8336
# Y55-59     8336  8336  8336   8336          8336
# Y60-64     8336  8336  8336   8336          8336
# Y65-69     8336  8336  8336   8336          8336
# Y70-74     7590  7590  7590   7590          7590
# Y75-79     7590  7590  7590   7590          7590
# Y80-84     7590  7590  7590   7590          7590
# Y_GE85     7590  7590  7590   7590          7590
# Y_LT5      8336  8336  8336   8336          8336

# %%
population_df = transform_population_df(population_df=population_df)

# %%
population_df
# Out:
#                 id                name  year  population powiat_numer
# 0     011212001000    Powiat bocheński  2000        6232         1201  \
# 1     011212001000    Powiat bocheński  2001        6020         1201
# 2     011212001000    Powiat bocheński  2002        5842         1201
# 3     011212001000    Powiat bocheński  2003        5704         1201
# 4     011212001000    Powiat bocheński  2004        5588         1201
# ...            ...                 ...   ...         ...          ...
# 1615  071427338000  Powiat żyrardowski  2017        1482         1438
# 1616  071427338000  Powiat żyrardowski  2018        1467         1438
# 1617  071427338000  Powiat żyrardowski  2019        1436         1438
# 1618  071427338000  Powiat żyrardowski  2020        1392         1438
# 1619  071427338000  Powiat żyrardowski  2021        1369         1438
#
#      age_group name_normalized
# 0        Y_LT5       bocheński
# 1        Y_LT5       bocheński
# 2        Y_LT5       bocheński
# 3        Y_LT5       bocheński
# 4        Y_LT5       bocheński
# ...        ...             ...
# 1615    Y_GE85     żyrardowski
# 1616    Y_GE85     żyrardowski
# 1617    Y_GE85     żyrardowski
# 1618    Y_GE85     żyrardowski
# 1619    Y_GE85     żyrardowski
#
# [147064 rows x 7 columns]

# %%
deaths_path = "/Users/nelatoma/Documents/icm/magisterka/zgony/MAGISTERKA_OFFICIAL/results/all_poviats_stats.csv"

# %%
total_df = get_total_df(deaths_path=deaths_path)

# %%
total_df
# Out:
#                wiek powiat_numer    powiat_nazwa  year wiek_eurostat  deaths
# 392           0 - 4          201   bolesławiecki  2000         Y_LT5       6  \
# 393           0 - 4          202  dzierżoniowski  2000         Y_LT5      10
# 394           0 - 4          203       głogowski  2000         Y_LT5       7
# 395           0 - 4          204        górowski  2000         Y_LT5       4
# 396           0 - 4          205        jaworski  2000         Y_LT5       4
# ...             ...          ...             ...   ...           ...     ...
# 174215  90 i więcej         3217         wałecki  2021        Y_GE85      81
# 174216  90 i więcej         3218         łobeski  2021        Y_GE85      68
# 174217  90 i więcej         3261        Koszalin  2021        Y_GE85     219
# 174218  90 i więcej         3262        Szczecin  2021        Y_GE85     956
# 174219  90 i więcej         3263     Świnoujście  2021        Y_GE85      55
#
#        name_normalized
# 392      bolesławiecki
# 393     dzierżoniowski
# 394          głogowski
# 395           górowski
# 396           jaworski
# ...                ...
# 174215         wałecki
# 174216         łobeski
# 174217        Koszalin
# 174218        Szczecin
# 174219     Świnoujście
#
# [158403 rows x 7 columns]

# %% [markdown]
# Warszawski i Warszawa w roku 2002, zlozone do kupy do Warszawy

# %%
total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'] = total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'].add(total_df.loc[((total_df['name_normalized'] == 'warszawski' ) & (total_df['year'] == '2002')), 'deaths'].values)

# %%
rows_to_drop = total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")

# %%
total_df.drop(rows_to_drop.index, inplace=True)

# %%
total_df.query("name_normalized == 'warszawski' and year == '2002'")
# Out:
# Empty DataFrame
# Columns: [wiek, powiat_numer, powiat_nazwa, year, wiek_eurostat, deaths, name_normalized]
# Index: []

# %%
population_df.query("name_normalized == 'warszawski' and year == '2002'")
# Out:
# Empty DataFrame
# Columns: [id, name, year, population, powiat_numer, age_group, name_normalized]
# Index: []

# %% [markdown]
# Pare renamow

# %%
total_df = total_df.rename(columns={'wiek_eurostat':'age_group'})

# %% [markdown]
# Grupy wiekowe 84-89 i 90 i wiecej zlozone razem

# %%
total_df.query("wiek_eurostat == 'Y_GE85' and name_normalized == 'bolesławiecki'")
# Out:
#                wiek powiat_numer   powiat_nazwa  year wiek_eurostat  deaths
# 7022        85 - 89          201  bolesławiecki  2000        Y_GE85      63  \
# 7412    90 i więcej          201  bolesławiecki  2000        Y_GE85      33
# 14822       85 - 89          201  bolesławiecki  2001        Y_GE85      52
# 15212   90 i więcej          201  bolesławiecki  2001        Y_GE85      38
# 22766       85 - 89          201  bolesławiecki  2002        Y_GE85      52
# 23164   90 i więcej          201  bolesławiecki  2002        Y_GE85      31
# 30690       85 - 89          201  bolesławiecki  2003        Y_GE85      42
# 31086   90 i więcej          201  bolesławiecki  2003        Y_GE85      41
# 38610       85 - 89          201  bolesławiecki  2004        Y_GE85      46
# 39006   90 i więcej          201  bolesławiecki  2004        Y_GE85      46
# 46530       85 - 89          201  bolesławiecki  2005        Y_GE85      61
# 46926   90 i więcej          201  bolesławiecki  2005        Y_GE85      41
# 54450       85 - 89          201  bolesławiecki  2006        Y_GE85      47
# 54846   90 i więcej          201  bolesławiecki  2006        Y_GE85      41
# 62370       85 - 89          201  bolesławiecki  2007        Y_GE85      58
# 62766   90 i więcej          201  bolesławiecki  2007        Y_GE85      39
# 70290       85 - 89          201  bolesławiecki  2008        Y_GE85      77
# 70686   90 i więcej          201  bolesławiecki  2008        Y_GE85      44
# 78210       85 - 89          201  bolesławiecki  2009        Y_GE85      94
# 78606   90 i więcej          201  bolesławiecki  2009        Y_GE85      32
# 86130       85 - 89          201  bolesławiecki  2010        Y_GE85     110
# 86526   90 i więcej          201  bolesławiecki  2010        Y_GE85      46
# 94050       85 - 89          201  bolesławiecki  2011        Y_GE85      98
# 94446   90 i więcej          201  bolesławiecki  2011        Y_GE85      55
# 101970      85 - 89          201  bolesławiecki  2012        Y_GE85     102
# 102366  90 i więcej          201  bolesławiecki  2012        Y_GE85      69
# 109908      85 - 89          201  bolesławiecki  2013        Y_GE85     111
# 110305  90 i więcej          201  bolesławiecki  2013        Y_GE85      56
# 117848      85 - 89          201  bolesławiecki  2014        Y_GE85     112
# 118245  90 i więcej          201  bolesławiecki  2014        Y_GE85      56
# 125788      85 - 89          201  bolesławiecki  2015        Y_GE85     108
# 126185  90 i więcej          201  bolesławiecki  2015        Y_GE85      82
# 133728      85 - 89          201  bolesławiecki  2016        Y_GE85     136
# 134125  90 i więcej          201  bolesławiecki  2016        Y_GE85      67
# 141668      85 - 89          201  bolesławiecki  2017        Y_GE85     136
# 142065  90 i więcej          201  bolesławiecki  2017        Y_GE85      72
# 149608      85 - 89          201  bolesławiecki  2018        Y_GE85     145
# 150005  90 i więcej          201  bolesławiecki  2018        Y_GE85      99
# 157548      85 - 89          201  bolesławiecki  2019        Y_GE85     141
# 157945  90 i więcej          201  bolesławiecki  2019        Y_GE85      97
# 165488      85 - 89          201  bolesławiecki  2020        Y_GE85     166
# 165885  90 i więcej          201  bolesławiecki  2020        Y_GE85     137
# 173428      85 - 89          201  bolesławiecki  2021        Y_GE85     196
# 173825  90 i więcej          201  bolesławiecki  2021        Y_GE85     155
#
#        name_normalized
# 7022     bolesławiecki
# 7412     bolesławiecki
# 14822    bolesławiecki
# 15212    bolesławiecki
# 22766    bolesławiecki
# 23164    bolesławiecki
# 30690    bolesławiecki
# 31086    bolesławiecki
# 38610    bolesławiecki
# 39006    bolesławiecki
# 46530    bolesławiecki
# 46926    bolesławiecki
# 54450    bolesławiecki
# 54846    bolesławiecki
# 62370    bolesławiecki
# 62766    bolesławiecki
# 70290    bolesławiecki
# 70686    bolesławiecki
# 78210    bolesławiecki
# 78606    bolesławiecki
# 86130    bolesławiecki
# 86526    bolesławiecki
# 94050    bolesławiecki
# 94446    bolesławiecki
# 101970   bolesławiecki
# 102366   bolesławiecki
# 109908   bolesławiecki
# 110305   bolesławiecki
# 117848   bolesławiecki
# 118245   bolesławiecki
# 125788   bolesławiecki
# 126185   bolesławiecki
# 133728   bolesławiecki
# 134125   bolesławiecki
# 141668   bolesławiecki
# 142065   bolesławiecki
# 149608   bolesławiecki
# 150005   bolesławiecki
# 157548   bolesławiecki
# 157945   bolesławiecki
# 165488   bolesławiecki
# 165885   bolesławiecki
# 173428   bolesławiecki
# 173825   bolesławiecki

# %% [markdown]
# Join

# %%
merged_df = get_CMR_table(population_df, total_df)

# %%
merged_df.query("age_group == 'Y_GE85' and name_normalized_pop == 'bolesławiecki'")
# Out:
#                   id                  name  year  population powiat_numer
# 144594  030210101000  Powiat bolesławiecki  2002         467          201  \
# 144595  030210101000  Powiat bolesławiecki  2002         467          201
# 144596  030210101000  Powiat bolesławiecki  2003         451          201
# 144597  030210101000  Powiat bolesławiecki  2003         451          201
# 144598  030210101000  Powiat bolesławiecki  2004         499          201
# 144599  030210101000  Powiat bolesławiecki  2004         499          201
# 144600  030210101000  Powiat bolesławiecki  2005         552          201
# 144601  030210101000  Powiat bolesławiecki  2005         552          201
# 144602  030210101000  Powiat bolesławiecki  2006         579          201
# 144603  030210101000  Powiat bolesławiecki  2006         579          201
# 144604  030210101000  Powiat bolesławiecki  2007         665          201
# 144605  030210101000  Powiat bolesławiecki  2007         665          201
# 144606  030210101000  Powiat bolesławiecki  2008         726          201
# 144607  030210101000  Powiat bolesławiecki  2008         726          201
# 144608  030210101000  Powiat bolesławiecki  2009         826          201
# 144609  030210101000  Powiat bolesławiecki  2009         826          201
# 144610  030210101000  Powiat bolesławiecki  2010         877          201
# 144611  030210101000  Powiat bolesławiecki  2010         877          201
# 144612  030210101000  Powiat bolesławiecki  2011         967          201
# 144613  030210101000  Powiat bolesławiecki  2011         967          201
# 144614  030210101000  Powiat bolesławiecki  2012        1002          201
# 144615  030210101000  Powiat bolesławiecki  2012        1002          201
# 144616  030210101000  Powiat bolesławiecki  2013        1086          201
# 144617  030210101000  Powiat bolesławiecki  2013        1086          201
# 144618  030210101000  Powiat bolesławiecki  2014        1208          201
# 144619  030210101000  Powiat bolesławiecki  2014        1208          201
# 144620  030210101000  Powiat bolesławiecki  2015        1342          201
# 144621  030210101000  Powiat bolesławiecki  2015        1342          201
# 144622  030210101000  Powiat bolesławiecki  2016        1446          201
# 144623  030210101000  Powiat bolesławiecki  2016        1446          201
# 144624  030210101000  Powiat bolesławiecki  2017        1556          201
# 144625  030210101000  Powiat bolesławiecki  2017        1556          201
# 144626  030210101000  Powiat bolesławiecki  2018        1583          201
# 144627  030210101000  Powiat bolesławiecki  2018        1583          201
# 144628  030210101000  Powiat bolesławiecki  2019        1711          201
# 144629  030210101000  Powiat bolesławiecki  2019        1711          201
# 144630  030210101000  Powiat bolesławiecki  2020        1725          201
# 144631  030210101000  Powiat bolesławiecki  2020        1725          201
# 144632  030210101000  Powiat bolesławiecki  2021        1712          201
# 144633  030210101000  Powiat bolesławiecki  2021        1712          201
#
#        age_group name_normalized_pop         wiek   powiat_nazwa  deaths
# 144594    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      52  \
# 144595    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      31
# 144596    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      42
# 144597    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      41
# 144598    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      46
# 144599    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      46
# 144600    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      61
# 144601    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      41
# 144602    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      47
# 144603    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      41
# 144604    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      58
# 144605    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      39
# 144606    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      77
# 144607    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      44
# 144608    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      94
# 144609    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      32
# 144610    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     110
# 144611    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      46
# 144612    Y_GE85       bolesławiecki      85 - 89  bolesławiecki      98
# 144613    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      55
# 144614    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     102
# 144615    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      69
# 144616    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     111
# 144617    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      56
# 144618    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     112
# 144619    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      56
# 144620    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     108
# 144621    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      82
# 144622    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     136
# 144623    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      67
# 144624    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     136
# 144625    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      72
# 144626    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     145
# 144627    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      99
# 144628    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     141
# 144629    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki      97
# 144630    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     166
# 144631    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki     137
# 144632    Y_GE85       bolesławiecki      85 - 89  bolesławiecki     196
# 144633    Y_GE85       bolesławiecki  90 i więcej  bolesławiecki     155
#
#        name_normalized_tot
# 144594       bolesławiecki
# 144595       bolesławiecki
# 144596       bolesławiecki
# 144597       bolesławiecki
# 144598       bolesławiecki
# 144599       bolesławiecki
# 144600       bolesławiecki
# 144601       bolesławiecki
# 144602       bolesławiecki
# 144603       bolesławiecki
# 144604       bolesławiecki
# 144605       bolesławiecki
# 144606       bolesławiecki
# 144607       bolesławiecki
# 144608       bolesławiecki
# 144609       bolesławiecki
# 144610       bolesławiecki
# 144611       bolesławiecki
# 144612       bolesławiecki
# 144613       bolesławiecki
# 144614       bolesławiecki
# 144615       bolesławiecki
# 144616       bolesławiecki
# 144617       bolesławiecki
# 144618       bolesławiecki
# 144619       bolesławiecki
# 144620       bolesławiecki
# 144621       bolesławiecki
# 144622       bolesławiecki
# 144623       bolesławiecki
# 144624       bolesławiecki
# 144625       bolesławiecki
# 144626       bolesławiecki
# 144627       bolesławiecki
# 144628       bolesławiecki
# 144629       bolesławiecki
# 144630       bolesławiecki
# 144631       bolesławiecki
# 144632       bolesławiecki
# 144633       bolesławiecki

# %%
len(total_df)
# Out:
# 158384

# %%
len(population_df)
# Out:
# 147064

# %%
len(merged_df)
# Out:
# 154654

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154654 entries, 0 to 154653
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   154654 non-null  object
#  1   name                 154654 non-null  object
#  2   year                 154654 non-null  object
#  3   population           154654 non-null  int64
#  4   powiat_numer         154654 non-null  object
#  5   age_group            154654 non-null  object
#  6   name_normalized_pop  154654 non-null  object
#  7   wiek                 154654 non-null  object
#  8   powiat_nazwa         154654 non-null  object
#  9   deaths               154654 non-null  int64
#  10  name_normalized_tot  154654 non-null  object
#  11  CMR                  154654 non-null  float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 14.2+ MB

# %%
grouped_df = pd.DataFrame(merged_df.groupby(['name_normalized_tot', 'powiat_numer', 'year', 'age_group'], as_index=False).sum(['population', 'deaths']))

# %%
grouped_df
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0           Biała Podlaska          661  2000    Y10-14        5248       0
# 1           Biała Podlaska          661  2000    Y15-19        5933       4
# 2           Biała Podlaska          661  2000    Y20-24        4701       5
# 3           Biała Podlaska          661  2000    Y25-29        4198       8
# 4           Biała Podlaska          661  2000    Y30-34        3680       4
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        7149     297
# 147060            żywiecki         2417  2021    Y75-79        4059     252
# 147061            żywiecki         2417  2021    Y80-84        3242     314
# 147062            żywiecki         2417  2021    Y_GE85        5836     596
# 147063            żywiecki         2417  2021     Y_LT5        7571       8
#
# [147064 rows x 6 columns]

# %%
grouped_df.query('age_group=="Y_GE85"')
# Out:
#        name_normalized_tot powiat_numer  year age_group
# 44          Biała Podlaska          661  2002    Y_GE85  \
# 62          Biała Podlaska          661  2003    Y_GE85
# 80          Biała Podlaska          661  2004    Y_GE85
# 98          Biała Podlaska          661  2005    Y_GE85
# 116         Biała Podlaska          661  2006    Y_GE85
# ...                    ...          ...   ...       ...
# 146990            żywiecki         2417  2017    Y_GE85
# 147008            żywiecki         2417  2018    Y_GE85
# 147026            żywiecki         2417  2019    Y_GE85
# 147044            żywiecki         2417  2020    Y_GE85
# 147062            żywiecki         2417  2021    Y_GE85
#
#                               id
# 44      060610961000060610961000  \
# 62      060610961000060610961000
# 80      060610961000060610961000
# 98      060610961000060610961000
# 116     060610961000060610961000
# ...                          ...
# 146990  012414417000012414417000
# 147008  012414417000012414417000
# 147026  012414417000012414417000
# 147044  012414417000012414417000
# 147062  012414417000012414417000
#
#                                                     name  population
# 44      Powiat m. Biała PodlaskaPowiat m. Biała Podlaska         696  \
# 62      Powiat m. Biała PodlaskaPowiat m. Biała Podlaska         636
# 80      Powiat m. Biała PodlaskaPowiat m. Biała Podlaska         660
# 98      Powiat m. Biała PodlaskaPowiat m. Biała Podlaska         716
# 116     Powiat m. Biała PodlaskaPowiat m. Biała Podlaska         738
# ...                                                  ...         ...
# 146990                    Powiat żywieckiPowiat żywiecki        5848
# 147008                    Powiat żywieckiPowiat żywiecki        6074
# 147026                    Powiat żywieckiPowiat żywiecki        6170
# 147044                    Powiat żywieckiPowiat żywiecki        5956
# 147062                    Powiat żywieckiPowiat żywiecki        5836
#
#                  name_normalized_pop                wiek
# 44      Biała PodlaskaBiała Podlaska  85 - 8990 i więcej  \
# 62      Biała PodlaskaBiała Podlaska  85 - 8990 i więcej
# 80      Biała PodlaskaBiała Podlaska  85 - 8990 i więcej
# 98      Biała PodlaskaBiała Podlaska  85 - 8990 i więcej
# 116     Biała PodlaskaBiała Podlaska  85 - 8990 i więcej
# ...                              ...                 ...
# 146990              żywieckiżywiecki  85 - 8990 i więcej
# 147008              żywieckiżywiecki  85 - 8990 i więcej
# 147026              żywieckiżywiecki  85 - 8990 i więcej
# 147044              żywieckiżywiecki  85 - 8990 i więcej
# 147062              żywieckiżywiecki  85 - 8990 i więcej
#
#                         powiat_nazwa  deaths
# 44      Biała PodlaskaBiała Podlaska      58
# 62      Biała PodlaskaBiała Podlaska      83
# 80      Biała PodlaskaBiała Podlaska      55
# 98      Biała PodlaskaBiała Podlaska      54
# 116     Biała PodlaskaBiała Podlaska      63
# ...                              ...     ...
# 146990              żywieckiżywiecki     470
# 147008              żywieckiżywiecki     465
# 147026              żywieckiżywiecki     472
# 147044              żywieckiżywiecki     653
# 147062              żywieckiżywiecki     596
#
# [7590 rows x 11 columns]

# %%
grouped_df['CMR'] = grouped_df['deaths']/grouped_df['population'] * 100000

# %%
grouped_df.query("age_group == 'Y_GE85' and name_normalized_tot == 'Biała Podlaska'")
# Out:
#     name_normalized_tot powiat_numer  year age_group  population  deaths
# 44       Biała Podlaska          661  2002    Y_GE85         696      58  \
# 62       Biała Podlaska          661  2003    Y_GE85         636      83
# 80       Biała Podlaska          661  2004    Y_GE85         660      55
# 98       Biała Podlaska          661  2005    Y_GE85         716      54
# 116      Biała Podlaska          661  2006    Y_GE85         738      63
# 134      Biała Podlaska          661  2007    Y_GE85         822      49
# 152      Biała Podlaska          661  2008    Y_GE85         918      56
# 170      Biała Podlaska          661  2009    Y_GE85        1008      74
# 188      Biała Podlaska          661  2010    Y_GE85        1076      85
# 206      Biała Podlaska          661  2011    Y_GE85        1184      80
# 224      Biała Podlaska          661  2012    Y_GE85        1280      77
# 242      Biała Podlaska          661  2013    Y_GE85        1356     116
# 260      Biała Podlaska          661  2014    Y_GE85        1472      89
# 278      Biała Podlaska          661  2015    Y_GE85        1566     100
# 296      Biała Podlaska          661  2016    Y_GE85        1642     120
# 314      Biała Podlaska          661  2017    Y_GE85        1714     124
# 332      Biała Podlaska          661  2018    Y_GE85        1764     126
# 350      Biała Podlaska          661  2019    Y_GE85        1786     148
# 368      Biała Podlaska          661  2020    Y_GE85        1902     168
# 386      Biała Podlaska          661  2021    Y_GE85        1904     168
#
#               CMR
# 44    8333.333333
# 62   13050.314465
# 80    8333.333333
# 98    7541.899441
# 116   8536.585366
# 134   5961.070560
# 152   6100.217865
# 170   7341.269841
# 188   7899.628253
# 206   6756.756757
# 224   6015.625000
# 242   8554.572271
# 260   6046.195652
# 278   6385.696041
# 296   7308.160780
# 314   7234.539090
# 332   7142.857143
# 350   8286.674132
# 368   8832.807571
# 386   8823.529412

# %%
grouped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147064 entries, 0 to 147063
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name_normalized_tot  147064 non-null  object
#  1   powiat_numer         147064 non-null  object
#  2   year                 147064 non-null  object
#  3   age_group            147064 non-null  object
#  4   population           147064 non-null  int64
#  5   deaths               147064 non-null  int64
#  6   CMR                  147064 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 7.9+ MB

# %%
grouped_df.to_csv('../results/CMR_age_groups_Y.csv', index=False)

# %% [markdown]
# ### Połączenie z dotychczasowymi danymi TOTAL dla latwiejszej wizualizacji

# %%
cmr_total_df = pd.read_csv('../results/CMR_total_Y.csv')

# %%
cmr_total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   8336 non-null   int64
#  1   name                 8336 non-null   object
#  2   year                 8336 non-null   int64
#  3   population           8336 non-null   int64
#  4   name_normalized_pop  8336 non-null   object
#  5   powiat_numer         8336 non-null   int64
#  6   wiek                 8336 non-null   object
#  7   powiat_nazwa         8336 non-null   object
#  8   wiek_eurostat        8336 non-null   object
#  9   deaths               8336 non-null   int64
#  10  name_normalized_tot  8336 non-null   object
#  11  CMR                  8336 non-null   float64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 781.6+ KB

# %%
cmr_total_copy_df = cmr_total_df.copy()

# %%
cmr_total_copy_df['year'] = cmr_total_copy_df['year'].astype('str')
cmr_total_copy_df['powiat_numer'] = cmr_total_copy_df['powiat_numer'].astype('str')
cmr_total_copy_df = cmr_total_copy_df.rename(columns={'wiek_eurostat':'age_group'})

# %%
cmr_total_copy_df.columns
# Out:
# Index(['id', 'name', 'year', 'population', 'name_normalized_pop',
#        'powiat_numer', 'wiek', 'powiat_nazwa', 'age_group', 'deaths',
#        'name_normalized_tot', 'CMR'],
#       dtype='object')

# %%
grouped_df.columns
# Out:
# Index(['name_normalized_tot', 'powiat_numer', 'year', 'age_group',
#        'population', 'deaths', 'CMR'],
#       dtype='object')

# %%
FINAL_DF = pd.concat([cmr_total_copy_df[grouped_df.columns], grouped_df])

# %%
FINAL_DF
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0                bocheński         1201  2000     TOTAL       97328     837  \
# 1                bocheński         1201  2001     TOTAL       97602     863
# 2                bocheński         1201  2002     TOTAL       97962     896
# 3                bocheński         1201  2003     TOTAL       98394     840
# 4                bocheński         1201  2004     TOTAL      100063     866
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        7149     297
# 147060            żywiecki         2417  2021    Y75-79        4059     252
# 147061            żywiecki         2417  2021    Y80-84        3242     314
# 147062            żywiecki         2417  2021    Y_GE85        5836     596
# 147063            żywiecki         2417  2021     Y_LT5        7571       8
#
#                  CMR
# 0         859.978629
# 1         884.203193
# 2         914.640371
# 3         853.710592
# 4         865.454763
# ...              ...
# 147059   4154.427193
# 147060   6208.425721
# 147061   9685.379395
# 147062  10212.474297
# 147063    105.666358
#
# [155400 rows x 7 columns]

# %%
len(cmr_total_copy_df) + len(grouped_df)
# Out:
# 155400

# %%
FINAL_DF.query('name_normalized_tot == "Warszawa" and age_group == "Y_GE85"')
# Out:
#       name_normalized_tot powiat_numer  year age_group  population  deaths
# 20968            Warszawa         1465  2002    Y_GE85       42404    3580  \
# 20986            Warszawa         1465  2003    Y_GE85       40808    3667
# 21004            Warszawa         1465  2004    Y_GE85       42146    3460
# 21022            Warszawa         1465  2005    Y_GE85       44692    3568
# 21040            Warszawa         1465  2006    Y_GE85       47662    3459
# 21058            Warszawa         1465  2007    Y_GE85       52092    3640
# 21076            Warszawa         1465  2008    Y_GE85       57746    3893
# 21094            Warszawa         1465  2009    Y_GE85       62520    4291
# 21112            Warszawa         1465  2010    Y_GE85       65456    4436
# 21130            Warszawa         1465  2011    Y_GE85       70842    4680
# 21148            Warszawa         1465  2012    Y_GE85       75558    4998
# 21166            Warszawa         1465  2013    Y_GE85       81338    5393
# 21184            Warszawa         1465  2014    Y_GE85       87690    5603
# 21202            Warszawa         1465  2015    Y_GE85       94854    6194
# 21220            Warszawa         1465  2016    Y_GE85      101082    6326
# 21238            Warszawa         1465  2017    Y_GE85      105406    6998
# 21256            Warszawa         1465  2018    Y_GE85      108722    7056
# 21274            Warszawa         1465  2019    Y_GE85      112282    7072
# 21292            Warszawa         1465  2020    Y_GE85      106446    8740
# 21310            Warszawa         1465  2021    Y_GE85      105906    8797
#
#                CMR
# 20968  8442.599755
# 20986  8985.983141
# 21004  8209.557253
# 21022  7983.531728
# 21040  7257.353867
# 21058  6987.637257
# 21076  6741.592491
# 21094  6863.403711
# 21112  6777.071621
# 21130  6606.250529
# 21148  6614.785992
# 21166  6630.357275
# 21184  6389.554111
# 21202  6530.035634
# 21220  6258.285352
# 21238  6639.090754
# 21256  6489.946837
# 21274  6298.427174
# 21292  8210.735960
# 21310  8306.422677

# %%
FINAL_DF.to_csv('../results/ALL_CMR_Y.csv', index=False)

# %% [markdown]
# # Dla kobiet

# %%
age_groups = """Y_LT5	72296
Y5-9	72297
Y10-14	72298
Y15-19	72299
Y20-24	47738
Y25-29	47696
Y30-34	47695
Y35-39	47716
Y40-44	47698
Y45-49	47727
Y50-54	47723
Y55-59	47702
Y60-64	47693
Y65-69	72241
Y70-74	76014
Y75-79	76015
Y80-84	76016
Y_GE85	76017"""

# Split the data into lines and then split each line into key and value
lines = age_groups.split("\n")
keys = []
values = []

for line in lines:
    key, value = line.split()
    keys.append(key)
    values.append(int(value))

# Create a dictionary from the keys and values lists
age_dict = dict(zip(keys, values))
print(age_dict)
# Out:
# {'Y_LT5': 72296, 'Y5-9': 72297, 'Y10-14': 72298, 'Y15-19': 72299, 'Y20-24': 47738, 'Y25-29': 47696, 'Y30-34': 47695, 'Y35-39': 47716, 'Y40-44': 47698, 'Y45-49': 47727, 'Y50-54': 47723, 'Y55-59': 47702, 'Y60-64': 47693, 'Y65-69': 72241, 'Y70-74': 76014, 'Y75-79': 76015, 'Y80-84': 76016, 'Y_GE85': 76017}

# %%
population_df = pd.DataFrame()

for k, v in age_dict.items():
    current_df = pd.DataFrame()
    page_0 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=0'
    page_1 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=1'
    page_2 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=2'
    page_3 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=3'
    df_0 = get_df(page_0)
    df_1 = get_df(page_1)
    df_2 = get_df(page_2)
    df_3 = get_df(page_3)
    dfs = [df_0, df_1, df_2, df_3]
    current_df = pd.concat(dfs, axis=0)
    current_df['age_group'] = str(k)
    population_df = pd.concat([population_df, current_df], axis=0)

# %%
population_df
# Out:
#                 id                name  year  value powiat_numer age_group
# 0     011212001000    Powiat bocheński  2000   3021         1201     Y_LT5
# 1     011212001000    Powiat bocheński  2001   2915         1201     Y_LT5
# 2     011212001000    Powiat bocheński  2002   2820         1201     Y_LT5
# 3     011212001000    Powiat bocheński  2003   2797         1201     Y_LT5
# 4     011212001000    Powiat bocheński  2004   2749         1201     Y_LT5
# ...            ...                 ...   ...    ...          ...       ...
# 1615  071427338000  Powiat żyrardowski  2017   1091         1438    Y_GE85
# 1616  071427338000  Powiat żyrardowski  2018   1074         1438    Y_GE85
# 1617  071427338000  Powiat żyrardowski  2019   1067         1438    Y_GE85
# 1618  071427338000  Powiat żyrardowski  2020   1040         1438    Y_GE85
# 1619  071427338000  Powiat żyrardowski  2021   1004         1438    Y_GE85
#
# [147064 rows x 6 columns]

# %%
population_df = transform_population_df(population_df=population_df)

# %%
population_df
# Out:
#                 id                name  year  population powiat_numer
# 0     011212001000    Powiat bocheński  2000        3021         1201  \
# 1     011212001000    Powiat bocheński  2001        2915         1201
# 2     011212001000    Powiat bocheński  2002        2820         1201
# 3     011212001000    Powiat bocheński  2003        2797         1201
# 4     011212001000    Powiat bocheński  2004        2749         1201
# ...            ...                 ...   ...         ...          ...
# 1615  071427338000  Powiat żyrardowski  2017        1091         1438
# 1616  071427338000  Powiat żyrardowski  2018        1074         1438
# 1617  071427338000  Powiat żyrardowski  2019        1067         1438
# 1618  071427338000  Powiat żyrardowski  2020        1040         1438
# 1619  071427338000  Powiat żyrardowski  2021        1004         1438
#
#      age_group name_normalized
# 0        Y_LT5       bocheński
# 1        Y_LT5       bocheński
# 2        Y_LT5       bocheński
# 3        Y_LT5       bocheński
# 4        Y_LT5       bocheński
# ...        ...             ...
# 1615    Y_GE85     żyrardowski
# 1616    Y_GE85     żyrardowski
# 1617    Y_GE85     żyrardowski
# 1618    Y_GE85     żyrardowski
# 1619    Y_GE85     żyrardowski
#
# [147064 rows x 7 columns]

# %%
deaths_path = "/Users/nelatoma/Documents/icm/magisterka/zgony/MAGISTERKA_OFFICIAL/results/all_poviats_stats_females.csv"

# %%
total_df = get_total_df(deaths_path=deaths_path)

# %%
total_df
# Out:
#                wiek powiat_numer    powiat_nazwa  year wiek_eurostat  deaths
# 392           0 - 4          201   bolesławiecki  2000         Y_LT5       3  \
# 393           0 - 4          202  dzierżoniowski  2000         Y_LT5       4
# 394           0 - 4          203       głogowski  2000         Y_LT5       3
# 395           0 - 4          204        górowski  2000         Y_LT5       2
# 396           0 - 4          205        jaworski  2000         Y_LT5       0
# ...             ...          ...             ...   ...           ...     ...
# 174215  90 i więcej         3217         wałecki  2021        Y_GE85      62
# 174216  90 i więcej         3218         łobeski  2021        Y_GE85      48
# 174217  90 i więcej         3261        Koszalin  2021        Y_GE85     164
# 174218  90 i więcej         3262        Szczecin  2021        Y_GE85     677
# 174219  90 i więcej         3263     Świnoujście  2021        Y_GE85      41
#
#        name_normalized
# 392      bolesławiecki
# 393     dzierżoniowski
# 394          głogowski
# 395           górowski
# 396           jaworski
# ...                ...
# 174215         wałecki
# 174216         łobeski
# 174217        Koszalin
# 174218        Szczecin
# 174219     Świnoujście
#
# [158403 rows x 7 columns]

# %%
total_df.query("powiat_nazwa == 'Warszawa'")
# Out:
#                wiek powiat_numer powiat_nazwa  year wiek_eurostat  deaths
# 16185         0 - 4         1465     Warszawa  2002         Y_LT5       0  \
# 16583         5 - 9         1465     Warszawa  2002          Y5-9       0
# 16981       10 - 14         1465     Warszawa  2002        Y10-14       0
# 17379       15 - 19         1465     Warszawa  2002        Y15-19       0
# 17777       20 - 24         1465     Warszawa  2002        Y20-24       0
# ...             ...          ...          ...   ...           ...     ...
# 172421      70 - 74         1465     Warszawa  2021        Y70-74    1251
# 172818      75 - 79         1465     Warszawa  2021        Y75-79    1264
# 173215      80 - 84         1465     Warszawa  2021        Y80-84    1815
# 173612      85 - 89         1465     Warszawa  2021        Y_GE85    2684
# 174009  90 i więcej         1465     Warszawa  2021        Y_GE85    3075
#
#        name_normalized
# 16185         Warszawa
# 16583         Warszawa
# 16981         Warszawa
# 17379         Warszawa
# 17777         Warszawa
# ...                ...
# 172421        Warszawa
# 172818        Warszawa
# 173215        Warszawa
# 173612        Warszawa
# 174009        Warszawa
#
# [380 rows x 7 columns]

# %%
total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'] = total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'].add(total_df.loc[((total_df['name_normalized'] == 'warszawski' ) & (total_df['year'] == '2002')), 'deaths'].values)

# %%
total_df.query("powiat_nazwa == 'Warszawa' and year == '2002'")
# Out:
#               wiek powiat_numer powiat_nazwa  year wiek_eurostat  deaths
# 16185        0 - 4         1465     Warszawa  2002         Y_LT5      32  \
# 16583        5 - 9         1465     Warszawa  2002          Y5-9       9
# 16981      10 - 14         1465     Warszawa  2002        Y10-14      11
# 17379      15 - 19         1465     Warszawa  2002        Y15-19      12
# 17777      20 - 24         1465     Warszawa  2002        Y20-24      21
# 18175      25 - 29         1465     Warszawa  2002        Y25-29      19
# 18573      30 - 34         1465     Warszawa  2002        Y30-34      30
# 18971      35 - 39         1465     Warszawa  2002        Y35-39      41
# 19369      40 - 44         1465     Warszawa  2002        Y40-44      90
# 19767      45 - 49         1465     Warszawa  2002        Y45-49     225
# 20165      50 - 54         1465     Warszawa  2002        Y50-54     342
# 20563      55 - 59         1465     Warszawa  2002        Y55-59     322
# 20961      60 - 64         1465     Warszawa  2002        Y60-64     458
# 21359      65 - 69         1465     Warszawa  2002        Y65-69     701
# 21757      70 - 74         1465     Warszawa  2002        Y70-74    1164
# 22155      75 - 79         1465     Warszawa  2002        Y75-79    1479
# 22553      80 - 84         1465     Warszawa  2002        Y80-84    1258
# 22951      85 - 89         1465     Warszawa  2002        Y_GE85    1279
# 23349  90 i więcej         1465     Warszawa  2002        Y_GE85    1375
#
#       name_normalized
# 16185        Warszawa
# 16583        Warszawa
# 16981        Warszawa
# 17379        Warszawa
# 17777        Warszawa
# 18175        Warszawa
# 18573        Warszawa
# 18971        Warszawa
# 19369        Warszawa
# 19767        Warszawa
# 20165        Warszawa
# 20563        Warszawa
# 20961        Warszawa
# 21359        Warszawa
# 21757        Warszawa
# 22155        Warszawa
# 22553        Warszawa
# 22951        Warszawa
# 23349        Warszawa

# %%
total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")
# Out:
#               wiek powiat_numer powiat_nazwa  year wiek_eurostat  deaths
# 16173        0 - 4         1431   warszawski  2002         Y_LT5      32  \
# 16571        5 - 9         1431   warszawski  2002          Y5-9       9
# 16969      10 - 14         1431   warszawski  2002        Y10-14      11
# 17367      15 - 19         1431   warszawski  2002        Y15-19      12
# 17765      20 - 24         1431   warszawski  2002        Y20-24      21
# 18163      25 - 29         1431   warszawski  2002        Y25-29      19
# 18561      30 - 34         1431   warszawski  2002        Y30-34      28
# 18959      35 - 39         1431   warszawski  2002        Y35-39      41
# 19357      40 - 44         1431   warszawski  2002        Y40-44      89
# 19755      45 - 49         1431   warszawski  2002        Y45-49     224
# 20153      50 - 54         1431   warszawski  2002        Y50-54     340
# 20551      55 - 59         1431   warszawski  2002        Y55-59     321
# 20949      60 - 64         1431   warszawski  2002        Y60-64     454
# 21347      65 - 69         1431   warszawski  2002        Y65-69     701
# 21745      70 - 74         1431   warszawski  2002        Y70-74    1160
# 22143      75 - 79         1431   warszawski  2002        Y75-79    1478
# 22541      80 - 84         1431   warszawski  2002        Y80-84    1258
# 22939      85 - 89         1431   warszawski  2002        Y_GE85    1274
# 23337  90 i więcej         1431   warszawski  2002        Y_GE85    1372
#
#       name_normalized
# 16173      warszawski
# 16571      warszawski
# 16969      warszawski
# 17367      warszawski
# 17765      warszawski
# 18163      warszawski
# 18561      warszawski
# 18959      warszawski
# 19357      warszawski
# 19755      warszawski
# 20153      warszawski
# 20551      warszawski
# 20949      warszawski
# 21347      warszawski
# 21745      warszawski
# 22143      warszawski
# 22541      warszawski
# 22939      warszawski
# 23337      warszawski

# %%
rows_to_drop = total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")

# %%
total_df.drop(rows_to_drop.index, inplace=True)

# %%
total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")
# Out:
# Empty DataFrame
# Columns: [wiek, powiat_numer, powiat_nazwa, year, wiek_eurostat, deaths, name_normalized]
# Index: []

# %%
population_df.query("name_normalized == 'warszawski' and year == '2002'")
# Out:
# Empty DataFrame
# Columns: [id, name, year, population, powiat_numer, age_group, name_normalized]
# Index: []

# %%
total_df = total_df.rename(columns={'wiek_eurostat':'age_group'})

# %%
merged_df = get_CMR_table(population_df, total_df)

# %%
merged_df
# Out:
#                   id                name  year  population powiat_numer
# 0       011212001000    Powiat bocheński  2000        3021         1201  \
# 1       011212001000    Powiat bocheński  2001        2915         1201
# 2       011212001000    Powiat bocheński  2002        2820         1201
# 3       011212001000    Powiat bocheński  2003        2797         1201
# 4       011212001000    Powiat bocheński  2004        2749         1201
# ...              ...                 ...   ...         ...          ...
# 154649  071427338000  Powiat żyrardowski  2019        1067         1438
# 154650  071427338000  Powiat żyrardowski  2020        1040         1438
# 154651  071427338000  Powiat żyrardowski  2020        1040         1438
# 154652  071427338000  Powiat żyrardowski  2021        1004         1438
# 154653  071427338000  Powiat żyrardowski  2021        1004         1438
#
#        age_group name_normalized_pop         wiek powiat_nazwa  deaths
# 0          Y_LT5           bocheński        0 - 4    bocheński       3  \
# 1          Y_LT5           bocheński        0 - 4    bocheński       3
# 2          Y_LT5           bocheński        0 - 4    bocheński       5
# 3          Y_LT5           bocheński        0 - 4    bocheński       2
# 4          Y_LT5           bocheński        0 - 4    bocheński       1
# ...          ...                 ...          ...          ...     ...
# 154649    Y_GE85         żyrardowski  90 i więcej  żyrardowski      71
# 154650    Y_GE85         żyrardowski      85 - 89  żyrardowski     108
# 154651    Y_GE85         żyrardowski  90 i więcej  żyrardowski     115
# 154652    Y_GE85         żyrardowski      85 - 89  żyrardowski     109
# 154653    Y_GE85         żyrardowski  90 i więcej  żyrardowski     105
#
#        name_normalized_tot
# 0                bocheński
# 1                bocheński
# 2                bocheński
# 3                bocheński
# 4                bocheński
# ...                    ...
# 154649         żyrardowski
# 154650         żyrardowski
# 154651         żyrardowski
# 154652         żyrardowski
# 154653         żyrardowski
#
# [154654 rows x 11 columns]

# %%
grouped_df = pd.DataFrame(merged_df.groupby(['name_normalized_tot', 'powiat_numer', 'year', 'age_group'], as_index=False).sum(['population', 'deaths']))

# %%
grouped_df
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0           Biała Podlaska          661  2000    Y10-14        2368       0
# 1           Biała Podlaska          661  2000    Y15-19        2991       3
# 2           Biała Podlaska          661  2000    Y20-24        2311       1
# 3           Biała Podlaska          661  2000    Y25-29        2047       2
# 4           Biała Podlaska          661  2000    Y30-34        1895       2
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        4023     126
# 147060            żywiecki         2417  2021    Y75-79        2498     108
# 147061            żywiecki         2417  2021    Y80-84        2119     163
# 147062            żywiecki         2417  2021    Y_GE85        4348     418
# 147063            żywiecki         2417  2021     Y_LT5        3663       4
#
# [147064 rows x 6 columns]

# %%
cmr_total_df = pd.read_csv('../results/CMR_total_females_Y.csv')

# %%
cmr_total_df
# Out:
#                id                name  year  population  powiat_numer
# 0     11212001000    Powiat bocheński  2000       49494          1201  \
# 1     11212001000    Powiat bocheński  2001       49594          1201
# 2     11212001000    Powiat bocheński  2002       49832          1201
# 3     11212001000    Powiat bocheński  2003       50118          1201
# 4     11212001000    Powiat bocheński  2004       50970          1201
# ...           ...                 ...   ...         ...           ...
# 8331  71427338000  Powiat żyrardowski  2017       39689          1438
# 8332  71427338000  Powiat żyrardowski  2018       39587          1438
# 8333  71427338000  Powiat żyrardowski  2019       39518          1438
# 8334  71427338000  Powiat żyrardowski  2020       39519          1438
# 8335  71427338000  Powiat żyrardowski  2021       39289          1438
#
#      name_normalized_pop    wiek powiat_nazwa wiek_eurostat  deaths
# 0              bocheński  Ogółem    bocheński         TOTAL     425  \
# 1              bocheński  Ogółem    bocheński         TOTAL     417
# 2              bocheński  Ogółem    bocheński         TOTAL     427
# 3              bocheński  Ogółem    bocheński         TOTAL     386
# 4              bocheński  Ogółem    bocheński         TOTAL     409
# ...                  ...     ...          ...           ...     ...
# 8331         żyrardowski  Ogółem  żyrardowski         TOTAL     460
# 8332         żyrardowski  Ogółem  żyrardowski         TOTAL     457
# 8333         żyrardowski  Ogółem  żyrardowski         TOTAL     463
# 8334         żyrardowski  Ogółem  żyrardowski         TOTAL     542
# 8335         żyrardowski  Ogółem  żyrardowski         TOTAL     625
#
#      name_normalized_tot          CMR
# 0              bocheński   858.689942
# 1              bocheński   840.827519
# 2              bocheński   856.879114
# 3              bocheński   770.182370
# 4              bocheński   802.432804
# ...                  ...          ...
# 8331         żyrardowski  1159.011313
# 8332         żyrardowski  1154.419380
# 8333         żyrardowski  1171.617997
# 8334         żyrardowski  1371.492194
# 8335         żyrardowski  1590.776044
#
# [8336 rows x 12 columns]

# %%
cmr_total_copy_df = cmr_total_df.copy()

# %%
cmr_total_copy_df['year'] = cmr_total_copy_df['year'].astype('str')
cmr_total_copy_df['powiat_numer'] = cmr_total_copy_df['powiat_numer'].astype('str')
cmr_total_copy_df = cmr_total_copy_df.rename(columns={'wiek_eurostat':'age_group'})

# %%
FINAL_DF = pd.concat([cmr_total_copy_df[grouped_df.columns], grouped_df])

# %%
FINAL_DF
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0                bocheński         1201  2000     TOTAL       49494     425
# 1                bocheński         1201  2001     TOTAL       49594     417
# 2                bocheński         1201  2002     TOTAL       49832     427
# 3                bocheński         1201  2003     TOTAL       50118     386
# 4                bocheński         1201  2004     TOTAL       50970     409
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        4023     126
# 147060            żywiecki         2417  2021    Y75-79        2498     108
# 147061            żywiecki         2417  2021    Y80-84        2119     163
# 147062            żywiecki         2417  2021    Y_GE85        4348     418
# 147063            żywiecki         2417  2021     Y_LT5        3663       4
#
# [155400 rows x 6 columns]

# %%
FINAL_DF.query('name_normalized_tot == "Warszawa" and age_group == "Y_GE85"')
# Out:
#       name_normalized_tot powiat_numer  year age_group  population  deaths
# 20968            Warszawa         1465  2002    Y_GE85       32418    2654
# 20986            Warszawa         1465  2003    Y_GE85       31248    2673
# 21004            Warszawa         1465  2004    Y_GE85       32088    2546
# 21022            Warszawa         1465  2005    Y_GE85       33708    2611
# 21040            Warszawa         1465  2006    Y_GE85       35520    2532
# 21058            Warszawa         1465  2007    Y_GE85       38376    2579
# 21076            Warszawa         1465  2008    Y_GE85       42004    2741
# 21094            Warszawa         1465  2009    Y_GE85       44946    3010
# 21112            Warszawa         1465  2010    Y_GE85       46314    3047
# 21130            Warszawa         1465  2011    Y_GE85       49590    3250
# 21148            Warszawa         1465  2012    Y_GE85       52452    3368
# 21166            Warszawa         1465  2013    Y_GE85       55888    3654
# 21184            Warszawa         1465  2014    Y_GE85       59788    3767
# 21202            Warszawa         1465  2015    Y_GE85       64244    4075
# 21220            Warszawa         1465  2016    Y_GE85       68596    4100
# 21238            Warszawa         1465  2017    Y_GE85       71752    4548
# 21256            Warszawa         1465  2018    Y_GE85       74132    4580
# 21274            Warszawa         1465  2019    Y_GE85       76754    4669
# 21292            Warszawa         1465  2020    Y_GE85       73898    5644
# 21310            Warszawa         1465  2021    Y_GE85       74096    5759

# %%
FINAL_DF['CMR'] = FINAL_DF['deaths']/FINAL_DF['population'] * 100000

# %%
FINAL_DF
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0                bocheński         1201  2000     TOTAL       49494     425  \
# 1                bocheński         1201  2001     TOTAL       49594     417
# 2                bocheński         1201  2002     TOTAL       49832     427
# 3                bocheński         1201  2003     TOTAL       50118     386
# 4                bocheński         1201  2004     TOTAL       50970     409
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        4023     126
# 147060            żywiecki         2417  2021    Y75-79        2498     108
# 147061            żywiecki         2417  2021    Y80-84        2119     163
# 147062            żywiecki         2417  2021    Y_GE85        4348     418
# 147063            żywiecki         2417  2021     Y_LT5        3663       4
#
#                 CMR
# 0        858.689942
# 1        840.827519
# 2        856.879114
# 3        770.182370
# 4        802.432804
# ...             ...
# 147059  3131.991051
# 147060  4323.458767
# 147061  7692.307692
# 147062  9613.615455
# 147063   109.200109
#
# [155400 rows x 7 columns]

# %%
FINAL_DF.query('powiat_numer == "1201" and age_group == "TOTAL"')
# Out:
#    name_normalized_tot powiat_numer  year age_group  population  deaths
# 0            bocheński         1201  2000     TOTAL       49494     425  \
# 1            bocheński         1201  2001     TOTAL       49594     417
# 2            bocheński         1201  2002     TOTAL       49832     427
# 3            bocheński         1201  2003     TOTAL       50118     386
# 4            bocheński         1201  2004     TOTAL       50970     409
# 5            bocheński         1201  2005     TOTAL       51170     429
# 6            bocheński         1201  2006     TOTAL       51440     408
# 7            bocheński         1201  2007     TOTAL       51680     441
# 8            bocheński         1201  2008     TOTAL       51849     437
# 9            bocheński         1201  2009     TOTAL       52118     457
# 10           bocheński         1201  2010     TOTAL       52465     424
# 11           bocheński         1201  2011     TOTAL       52754     417
# 12           bocheński         1201  2012     TOTAL       53015     420
# 13           bocheński         1201  2013     TOTAL       53140     461
# 14           bocheński         1201  2014     TOTAL       53289     462
# 15           bocheński         1201  2015     TOTAL       53440     456
# 16           bocheński         1201  2016     TOTAL       53636     454
# 17           bocheński         1201  2017     TOTAL       53772     447
# 18           bocheński         1201  2018     TOTAL       53922     428
# 19           bocheński         1201  2019     TOTAL       54023     422
# 20           bocheński         1201  2020     TOTAL       54085     575
# 21           bocheński         1201  2021     TOTAL       54013     512
#
#             CMR
# 0    858.689942
# 1    840.827519
# 2    856.879114
# 3    770.182370
# 4    802.432804
# 5    838.381864
# 6    793.157076
# 7    853.328173
# 8    842.832070
# 9    876.856364
# 10   808.157819
# 11   790.461387
# 12   792.228615
# 13   867.519759
# 14   866.970669
# 15   853.293413
# 16   846.446417
# 17   831.287659
# 18   793.739105
# 19   781.148770
# 20  1063.141352
# 21   947.919945

# %%
FINAL_DF.to_csv('../results/ALL_CMR_FEMALES_Y.csv', index=False)

# %% [markdown]
# # Dla męzczyzn

# %%
age_groups = """Y_LT5	72301
Y5-9	72302
Y10-14	72303
Y15-19	72304
Y20-24	47711
Y25-29	47736
Y30-34	47724
Y35-39	47712
Y40-44	47725
Y45-49	47728
Y50-54	47706
Y55-59	47715
Y60-64	47721
Y65-69	72243
Y70-74	76018
Y75-79	76019
Y80-84	76020
Y_GE85	76021"""

# Split the data into lines and then split each line into key and value
lines = age_groups.split("\n")
keys = []
values = []

for line in lines:
    key, value = line.split()
    keys.append(key)
    values.append(int(value))

# Create a dictionary from the keys and values lists
age_dict = dict(zip(keys, values))
print(age_dict)
# Out:
# {'Y_LT5': 72301, 'Y5-9': 72302, 'Y10-14': 72303, 'Y15-19': 72304, 'Y20-24': 47711, 'Y25-29': 47736, 'Y30-34': 47724, 'Y35-39': 47712, 'Y40-44': 47725, 'Y45-49': 47728, 'Y50-54': 47706, 'Y55-59': 47715, 'Y60-64': 47721, 'Y65-69': 72243, 'Y70-74': 76018, 'Y75-79': 76019, 'Y80-84': 76020, 'Y_GE85': 76021}

# %%
population_df = pd.DataFrame()

for k, v in age_dict.items():
    current_df = pd.DataFrame()
    page_0 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=0'
    page_1 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=1'
    page_2 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=2'
    page_3 = f'https://bdl.stat.gov.pl/api/v1/data/by-variable/{v}?unit-level=5&year=2000&year=2001&year=2002&year=2003&year=2004&year=2005&year=2006&year=2007&year=2008&year=2009&year=2010&year=2011&year=2012&year=2013&year=2014&year=2015&year=2016&year=2017&year=2018&year=2019&year=2020&year=2021&page-size=100&page=3'
    df_0 = get_df(page_0)
    df_1 = get_df(page_1)
    df_2 = get_df(page_2)
    df_3 = get_df(page_3)
    dfs = [df_0, df_1, df_2, df_3]
    current_df = pd.concat(dfs, axis=0)
    current_df['age_group'] = str(k)
    population_df = pd.concat([population_df, current_df], axis=0)

# %%
population_df
# Out:
#                 id                name  year  value powiat_numer age_group
# 0     011212001000    Powiat bocheński  2000   3211         1201     Y_LT5
# 1     011212001000    Powiat bocheński  2001   3105         1201     Y_LT5
# 2     011212001000    Powiat bocheński  2002   3022         1201     Y_LT5
# 3     011212001000    Powiat bocheński  2003   2907         1201     Y_LT5
# 4     011212001000    Powiat bocheński  2004   2839         1201     Y_LT5
# ...            ...                 ...   ...    ...          ...       ...
# 1615  071427338000  Powiat żyrardowski  2017    391         1438    Y_GE85
# 1616  071427338000  Powiat żyrardowski  2018    393         1438    Y_GE85
# 1617  071427338000  Powiat żyrardowski  2019    369         1438    Y_GE85
# 1618  071427338000  Powiat żyrardowski  2020    352         1438    Y_GE85
# 1619  071427338000  Powiat żyrardowski  2021    365         1438    Y_GE85
#
# [147064 rows x 6 columns]

# %%
population_df = transform_population_df(population_df=population_df)

# %%
deaths_path = "/Users/nelatoma/Documents/icm/magisterka/zgony/MAGISTERKA_OFFICIAL/results/all_poviats_stats_males.csv"

# %%
total_df = get_total_df(deaths_path=deaths_path)

# %%
total_df
# Out:
#                wiek powiat_numer    powiat_nazwa  year wiek_eurostat  deaths
# 392           0 - 4          201   bolesławiecki  2000         Y_LT5       3  \
# 393           0 - 4          202  dzierżoniowski  2000         Y_LT5       6
# 394           0 - 4          203       głogowski  2000         Y_LT5       4
# 395           0 - 4          204        górowski  2000         Y_LT5       2
# 396           0 - 4          205        jaworski  2000         Y_LT5       4
# ...             ...          ...             ...   ...           ...     ...
# 174215  90 i więcej         3217         wałecki  2021        Y_GE85      19
# 174216  90 i więcej         3218         łobeski  2021        Y_GE85      20
# 174217  90 i więcej         3261        Koszalin  2021        Y_GE85      55
# 174218  90 i więcej         3262        Szczecin  2021        Y_GE85     279
# 174219  90 i więcej         3263     Świnoujście  2021        Y_GE85      14
#
#        name_normalized
# 392      bolesławiecki
# 393     dzierżoniowski
# 394          głogowski
# 395           górowski
# 396           jaworski
# ...                ...
# 174215         wałecki
# 174216         łobeski
# 174217        Koszalin
# 174218        Szczecin
# 174219     Świnoujście
#
# [158403 rows x 7 columns]

# %%
total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")
# Out:
#               wiek powiat_numer powiat_nazwa  year wiek_eurostat  deaths
# 16173        0 - 4         1431   warszawski  2002         Y_LT5      38  \
# 16571        5 - 9         1431   warszawski  2002          Y5-9       7
# 16969      10 - 14         1431   warszawski  2002        Y10-14      11
# 17367      15 - 19         1431   warszawski  2002        Y15-19      38
# 17765      20 - 24         1431   warszawski  2002        Y20-24      78
# 18163      25 - 29         1431   warszawski  2002        Y25-29      65
# 18561      30 - 34         1431   warszawski  2002        Y30-34      90
# 18959      35 - 39         1431   warszawski  2002        Y35-39      89
# 19357      40 - 44         1431   warszawski  2002        Y40-44     234
# 19755      45 - 49         1431   warszawski  2002        Y45-49     449
# 20153      50 - 54         1431   warszawski  2002        Y50-54     621
# 20551      55 - 59         1431   warszawski  2002        Y55-59     560
# 20949      60 - 64         1431   warszawski  2002        Y60-64     667
# 21347      65 - 69         1431   warszawski  2002        Y65-69    1041
# 21745      70 - 74         1431   warszawski  2002        Y70-74    1365
# 22143      75 - 79         1431   warszawski  2002        Y75-79    1314
# 22541      80 - 84         1431   warszawski  2002        Y80-84     849
# 22939      85 - 89         1431   warszawski  2002        Y_GE85     531
# 23337  90 i więcej         1431   warszawski  2002        Y_GE85     394
#
#       name_normalized
# 16173      warszawski
# 16571      warszawski
# 16969      warszawski
# 17367      warszawski
# 17765      warszawski
# 18163      warszawski
# 18561      warszawski
# 18959      warszawski
# 19357      warszawski
# 19755      warszawski
# 20153      warszawski
# 20551      warszawski
# 20949      warszawski
# 21347      warszawski
# 21745      warszawski
# 22143      warszawski
# 22541      warszawski
# 22939      warszawski
# 23337      warszawski

# %%
total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'] = total_df.loc[((total_df['name_normalized'] == 'Warszawa' ) & (total_df['year'] == '2002')), 'deaths'].add(total_df.loc[((total_df['name_normalized'] == 'warszawski' ) & (total_df['year'] == '2002')), 'deaths'].values)

# %%
total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")
# Out:
#               wiek powiat_numer powiat_nazwa  year wiek_eurostat  deaths
# 16173        0 - 4         1431   warszawski  2002         Y_LT5      38  \
# 16571        5 - 9         1431   warszawski  2002          Y5-9       7
# 16969      10 - 14         1431   warszawski  2002        Y10-14      11
# 17367      15 - 19         1431   warszawski  2002        Y15-19      38
# 17765      20 - 24         1431   warszawski  2002        Y20-24      78
# 18163      25 - 29         1431   warszawski  2002        Y25-29      65
# 18561      30 - 34         1431   warszawski  2002        Y30-34      90
# 18959      35 - 39         1431   warszawski  2002        Y35-39      89
# 19357      40 - 44         1431   warszawski  2002        Y40-44     234
# 19755      45 - 49         1431   warszawski  2002        Y45-49     449
# 20153      50 - 54         1431   warszawski  2002        Y50-54     621
# 20551      55 - 59         1431   warszawski  2002        Y55-59     560
# 20949      60 - 64         1431   warszawski  2002        Y60-64     667
# 21347      65 - 69         1431   warszawski  2002        Y65-69    1041
# 21745      70 - 74         1431   warszawski  2002        Y70-74    1365
# 22143      75 - 79         1431   warszawski  2002        Y75-79    1314
# 22541      80 - 84         1431   warszawski  2002        Y80-84     849
# 22939      85 - 89         1431   warszawski  2002        Y_GE85     531
# 23337  90 i więcej         1431   warszawski  2002        Y_GE85     394
#
#       name_normalized
# 16173      warszawski
# 16571      warszawski
# 16969      warszawski
# 17367      warszawski
# 17765      warszawski
# 18163      warszawski
# 18561      warszawski
# 18959      warszawski
# 19357      warszawski
# 19755      warszawski
# 20153      warszawski
# 20551      warszawski
# 20949      warszawski
# 21347      warszawski
# 21745      warszawski
# 22143      warszawski
# 22541      warszawski
# 22939      warszawski
# 23337      warszawski

# %%
rows_to_drop = total_df.query("powiat_nazwa == 'warszawski' and year == '2002'")

total_df.drop(rows_to_drop.index, inplace=True)

# %%
total_df = total_df.rename(columns={'wiek_eurostat':'age_group'})

# %%
merged_df = get_CMR_table(population_df, total_df)

# %%
merged_df
# Out:
#                   id                name  year  population powiat_numer
# 0       011212001000    Powiat bocheński  2000        3211         1201  \
# 1       011212001000    Powiat bocheński  2001        3105         1201
# 2       011212001000    Powiat bocheński  2002        3022         1201
# 3       011212001000    Powiat bocheński  2003        2907         1201
# 4       011212001000    Powiat bocheński  2004        2839         1201
# ...              ...                 ...   ...         ...          ...
# 154649  071427338000  Powiat żyrardowski  2019         369         1438
# 154650  071427338000  Powiat żyrardowski  2020         352         1438
# 154651  071427338000  Powiat żyrardowski  2020         352         1438
# 154652  071427338000  Powiat żyrardowski  2021         365         1438
# 154653  071427338000  Powiat żyrardowski  2021         365         1438
#
#        age_group name_normalized_pop         wiek powiat_nazwa  deaths
# 0          Y_LT5           bocheński        0 - 4    bocheński       5  \
# 1          Y_LT5           bocheński        0 - 4    bocheński       6
# 2          Y_LT5           bocheński        0 - 4    bocheński       3
# 3          Y_LT5           bocheński        0 - 4    bocheński       4
# 4          Y_LT5           bocheński        0 - 4    bocheński       2
# ...          ...                 ...          ...          ...     ...
# 154649    Y_GE85         żyrardowski  90 i więcej  żyrardowski      36
# 154650    Y_GE85         żyrardowski      85 - 89  żyrardowski      60
# 154651    Y_GE85         żyrardowski  90 i więcej  żyrardowski      38
# 154652    Y_GE85         żyrardowski      85 - 89  żyrardowski      41
# 154653    Y_GE85         żyrardowski  90 i więcej  żyrardowski      40
#
#        name_normalized_tot
# 0                bocheński
# 1                bocheński
# 2                bocheński
# 3                bocheński
# 4                bocheński
# ...                    ...
# 154649         żyrardowski
# 154650         żyrardowski
# 154651         żyrardowski
# 154652         żyrardowski
# 154653         żyrardowski
#
# [154654 rows x 11 columns]

# %%
grouped_df = pd.DataFrame(merged_df.groupby(['name_normalized_tot', 'powiat_numer', 'year', 'age_group'], as_index=False).sum(['population', 'deaths']))

# %%
grouped_df
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 0           Biała Podlaska          661  2000    Y10-14        2880       0
# 1           Biała Podlaska          661  2000    Y15-19        2942       1
# 2           Biała Podlaska          661  2000    Y20-24        2390       4
# 3           Biała Podlaska          661  2000    Y25-29        2151       6
# 4           Biała Podlaska          661  2000    Y30-34        1785       2
# ...                    ...          ...   ...       ...         ...     ...
# 147059            żywiecki         2417  2021    Y70-74        3126     171
# 147060            żywiecki         2417  2021    Y75-79        1561     144
# 147061            żywiecki         2417  2021    Y80-84        1123     151
# 147062            żywiecki         2417  2021    Y_GE85        1488     178
# 147063            żywiecki         2417  2021     Y_LT5        3908       4
#
# [147064 rows x 6 columns]

# %%
cmr_total_df = pd.read_csv('../results/CMR_total_males_Y.csv')

# %%
cmr_total_copy_df = cmr_total_df.copy()

# %%
cmr_total_copy_df['year'] = cmr_total_copy_df['year'].astype('str')
cmr_total_copy_df['powiat_numer'] = cmr_total_copy_df['powiat_numer'].astype('str')
cmr_total_copy_df = cmr_total_copy_df.rename(columns={'wiek_eurostat':'age_group'})

# %%
FINAL_DF = pd.concat([cmr_total_copy_df[grouped_df.columns], grouped_df])

# %%
FINAL_DF['CMR'] = FINAL_DF['deaths']/FINAL_DF['population'] * 100000

# %%
FINAL_DF.query('age_group == "Y40-44"')
# Out:
#        name_normalized_tot powiat_numer  year age_group  population  deaths
# 6           Biała Podlaska          661  2000    Y40-44        2469      18  \
# 20          Biała Podlaska          661  2001    Y40-44        2359      22
# 34          Biała Podlaska          661  2002    Y40-44        2231       7
# 52          Biała Podlaska          661  2003    Y40-44        2114       7
# 70          Biała Podlaska          661  2004    Y40-44        2006      12
# ...                    ...          ...   ...       ...         ...     ...
# 146980            żywiecki         2417  2017    Y40-44        5711      18
# 146998            żywiecki         2417  2018    Y40-44        5760      23
# 147016            żywiecki         2417  2019    Y40-44        5776      14
# 147034            żywiecki         2417  2020    Y40-44        5862      15
# 147052            żywiecki         2417  2021    Y40-44        5878      37
#
#                CMR
# 6       729.040097
# 20      932.598559
# 34      313.760645
# 52      331.125828
# 70      598.205384
# ...            ...
# 146980  315.181229
# 146998  399.305556
# 147016  242.382271
# 147034  255.885363
# 147052  629.465805
#
# [8336 rows x 7 columns]

# %%
FINAL_DF.to_csv('../results/ALL_CMR_MALES_Y.csv', index=False)
